# %% [markdown]
# # Barlists

# %%
import deetly

# %%
# Create datastory
description = """
Barlist examples
"""

story = {
    "name": "Barlist examples",
    "description":description, 
    "author": "deetly",
    "keywords":["barlist","examples"],
    "theme":"examples",
    "license": "MIT"
}

ds = deetly.story(story)

# %%
spec = {
  "data": [
    {
      "year": 2018,
      "name": "Telemark",
      "value": 50
    },
    {
      "year": 2018,
      "name": "Sogn og Fjordane",
      "value": 40
    },
    {
      "year": 2019,
      "name": "Sogn og Fjordane",
      "value": 40
    },
    {
      "year": 2018,
      "name": "Troms",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Nordland",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Nord-Trøndelag",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Møre og Romsdal",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Sør-Trøndelag",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Oppland",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Hordaland",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Vestfold",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Aust-Agder",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Troms",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Nordland",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Nord-Trøndelag",
      "value": 30
    },
    {
      "year": 2019,
      "name": "Sør-Trøndelag",
      "value": 30
    },
    {
      "year": 2019,
      "name": "Oppland",
      "value": 30
    },
    {
      "year": 2017,
      "name": "Hordaland",
      "value": 30
    },
    {
      "year": 2018,
      "name": "Rogaland",
      "value": 29
    },
    {
      "year": 2017,
      "name": "Rogaland",
      "value": 29
    },
    {
      "year": 2018,
      "name": "Buskerud",
      "value": 25
    },
    {
      "year": 2017,
      "name": "Buskerud",
      "value": 25
    },
    {
      "year": 2018,
      "name": "Finnmark",
      "value": 20
    },
    {
      "year": 2018,
      "name": "Hedmark",
      "value": 20
    },
    {
      "year": 2018,
      "name": "Vest-Agder",
      "value": 20
    },
    {
      "year": 2018,
      "name": "Finnmark",
      "value": 20
    },
    {
      "year": 2019,
      "name": "Møre og Romsdal",
      "value": 20
    },
    {
      "year": 2017,
      "name": "Hedmark",
      "value": 20
    },
    {
      "year": 2018,
      "name": "Akershus",
      "value": 15
    },
    {
      "year": 2017,
      "name": "Akershus",
      "value": 15
    },
    {
      "year": 2018,
      "name": "Oslo",
      "value": 14
    },
    {
      "year": 2017,
      "name": "Oslo",
      "value": 14
    },
    {
      "year": 2018,
      "name": "Svalbard",
      "value": 10
    },
    {
      "year": 2018,
      "name": "Svalbard",
      "value": 10
    },
    {
      "year": 2018,
      "name": "Østfold",
      "value": 4
    }
  ],
  "layout": {
    "title": "Barchart title",
    "columns": [
      {
        "name": "Fylke",
        "selector": "name",
        "sortable": True
      },
      {
        "name": "Verdi",
        "selector": "value",
        "sortable": True
      }
    ],
    "sortable": True
  },
  "filter": {
    "selector": "year",
    "type": "slider",
    "values": [
      {
        "value": 2017,
        "label": "2017",
        "active": True
      },
      {
        "value": 2018,
        "label": "2018"
      },
      {
        "value": 2019,
        "label": "2019"
      }
    ]
  }
}

# %%
ds.barlist(spec, "Filtered", "Filtered")

# %%
ds.publish()
# Out:
# Publishing story Barlist examples to the examples space...
# Published at: https://public.deetly.com/examples/5843add3d443225dceaf29af434b3240
