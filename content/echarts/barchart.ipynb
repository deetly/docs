# %% [markdown]
# # Bar chart
#
# >Basic bar chart

# %%
import deetly
import pandas as pd

from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.globals import ChartType

# %%
# Create datastory
metadata = {
    "name": "EChart Barchart examples",
    "keywords": ["bar","barchart","examples"]
}

ds = deetly.story(metadata)

# %%
g = (Bar()
    .add_xaxis(["Tokyo", "Delhi", "Shanghai", "São Paulo", "Mexico City", "Cairo"])
    .add_yaxis('Population', [37.4, 28.5, 25.6, 21.6, 21.6, 20.1])
    .set_global_opts(title_opts=opts.TitleOpts(title="Worlds largest cities", subtitle="UN 2018 estimates. Million"))
)

g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="160d2a266d1347889ff5a723e7605e8e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_160d2a266d1347889ff5a723e7605e8e = echarts.init(
#                     document.getElementById('160d2a266d1347889ff5a723e7605e8e'), 'white', {renderer: 'canvas'});
#                 var option_160d2a266d1347889ff5a723e7605e8e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
ds.echart(g, "World cities")

# %%
g = (Bar()
    .add_xaxis(["A", "B", "C"])
    .add_yaxis("series0", [1, 2, 4])
    .add_yaxis("series1", [2, 3, 6])
    .add_yaxis("series2", [5, 8, 7])
    .set_series_opts(stack="stack")
)
g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="148c534d5382403bbb321ee431f75d97" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_148c534d5382403bbb321ee431f75d97 = echarts.init(
#                     document.getElementById('148c534d5382403bbb321ee431f75d97'), 'white', {renderer: 'canvas'});
#                 var option_148c534d5382403bbb321ee431f75d97 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
ds.echart(g, "Stacked")

# %%
g = (Bar()
    .add_xaxis(["A", "B", "C"])
    .add_yaxis("series0", [1, 2, 4])
    .set_global_opts(
        graphic_opts=[
            opts.GraphicImage(
                graphic_item=opts.GraphicItem(
                    id_="logo",
                    left=20,
                    bottom=20,
                    z=10,
                    bounding="raw",
                    origin=[75, 75],
                ),
                graphic_imagestyle_opts=opts.GraphicImageStyleOpts(
                    image="https://public.deetly.com/favicon.ico",
                    width=20,
                    height=20,
                    opacity=1,
                ),
            )
        ]
    )
)
g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a9122bbe58b54c2c89f60652518313cf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a9122bbe58b54c2c89f60652518313cf = echarts.init(
#                     document.getElementById('a9122bbe58b54c2c89f60652518313cf'), 'white', {renderer: 'canvas'});
#                 var option_a9122bbe58b54c2c89f60652518313cf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
ds.echart(g, "With logo")

# %%
from pyecharts.commons.utils import JsCode

g = (
    Bar(
        init_opts=opts.InitOpts(
            bg_color={
                "type": "pattern",
                "image": JsCode("img"),
                "repeat": "no-repeat",
            }
        )
    )
    .add_xaxis(["A", "B", "C"])
    .add_yaxis("series0", [1, 2, 4])
    .add_yaxis("series1", [2, 3, 6])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="Bar",
            subtitle="with bg",
            title_textstyle_opts=opts.TextStyleOpts(color="white"),
        )
    )
)

g.add_js_funcs(
    """
    var img = new Image(); img.src = 'https://raw.githubusercontent.com/deetly/docs/master/images/gaspar-manuel-zaldo-5YZU84pvH8Y-unsplash.jpg?token=AAVTYSSZY44Z2AIEB62JUCDAJDFB6';
    """
)

g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="723d20cd893144b7a497301018b8d6fb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_723d20cd893144b7a497301018b8d6fb = echarts.init(
#                     document.getElementById('723d20cd893144b7a497301018b8d6fb'), 'white', {renderer: 'canvas'});
#
#     var img = new Image(); img.src = 'https://raw.githubusercontent.com/deetly/docs/master/images/gaspar-manuel-zaldo-5YZU84pvH8Y-unsplash.jpg?token=AAVTYSSZY44Z2AIEB62JUCDAJDFB6';
#
#                 var option_723d20cd893144b7a497301018b8d6fb = {
#     "backgroundColor": {
#         "type": "pattern",
#         "image": img,
#         "repeat": "no-repeat"
#     },
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
# ...

# %%
ds.publish()
# Out:
# Publishing story EChart Barchart examples to the examples space...
# Published at: https://public.deetly.com/examples/2a8763248cf575b9cd23b9123b3c56bd
