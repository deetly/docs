# %% [markdown]
# # Sankey chart
#
# >Basic sankey charts

# %%
import deetly
import pandas as pd

from pyecharts.charts import Sankey
from pyecharts import options as opts
from pyecharts.globals import ChartType

# %%
# Create datastory
metadata = {
    "name": "EChart Sankey examples",
    "keywords": ["line","linechart","chart","examples"]
}

ds = deetly.story(metadata)

# %%
nodes = [{"name": "category1"}, {"name": "category2"}, {"name": "category3"}]

links = [
    {"source": "category1", "target": "category2", "value": 10},
    {"source": "category2", "target": "category3", "value": 15},
]

g = Sankey().add(
    "sankey",
    nodes,
    links,
    linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
    label_opts=opts.LabelOpts(position="right"),
)

g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d131e723bb654880b8e576f36d976124" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d131e723bb654880b8e576f36d976124 = echarts.init(
#                     document.getElementById('d131e723bb654880b8e576f36d976124'), 'white', {renderer: 'canvas'});
#                 var option_d131e723bb654880b8e576f36d976124 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "sankey",
#             "data": [
#                 {
#                     "name": "category1"
#                 },
#                 {
#                     "name": "category2"
#                 },
#                 {
#                     "name": "category3"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "category1",
#                     "target": "category2",
#                     "value": 10
#                 },
#                 {
#                     "source": "category2",
#                     "target": "category3",
#                     "value": 15
#                 }
#             ],
#             "left": "5%",
#             "top": "5%",
#             "right": "20%",
#             "bottom": "5%",
#             "nodeWidth": 20,
#             "nodeGap": 8,
#             "nodeAlign": "justify",
#             "layoutIteration": 32,
#             "orient": "horizontal",
#             "draggable": true,
#             "focusNodeAdjacency": false,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 0.2,
#                 "curveness": 0.5,
#                 "type": "solid",
#                 "color": "source"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "sankey"
#             ],
#             "selected": {
#                 "sankey": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_d131e723bb654880b8e576f36d976124.setOption(option_d131e723bb654880b8e576f36d976124);
#         });
#     </script>

# %%
ds.echart(g, "Horizontal Sankey sample")

# %%
nodes = [
    {"name": "a"},
    {"name": "b"},
    {"name": "a1"},
    {"name": "b1"},
    {"name": "c"},
    {"name": "e"},
]
links = [
    {"source": "a", "target": "a1", "value": 5},
    {"source": "e", "target": "b", "value": 3},
    {"source": "a", "target": "b1", "value": 3},
    {"source": "b1", "target": "a1", "value": 1},
    {"source": "b1", "target": "c", "value": 2},
    {"source": "b", "target": "c", "value": 1},
]

g = Sankey().add(
    "sankey",
    nodes,
    links,
    pos_bottom="10%",
    focus_node_adjacency="allEdges",
    orient="vertical",
    levels=[
        opts.SankeyLevelsOpts(
            depth=0,
            itemstyle_opts=opts.ItemStyleOpts(color="#eee"),
            linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
        )
    ],
    linestyle_opt=opts.LineStyleOpts(opacity=0.4, curve=0.5, color="source"),
    label_opts=opts.LabelOpts(position="right"),
)

g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e8e30792a7fe4dc28ef68bb102832c6c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e8e30792a7fe4dc28ef68bb102832c6c = echarts.init(
#                     document.getElementById('e8e30792a7fe4dc28ef68bb102832c6c'), 'white', {renderer: 'canvas'});
#                 var option_e8e30792a7fe4dc28ef68bb102832c6c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "sankey",
#             "data": [
#                 {
#                     "name": "a"
#                 },
#                 {
#                     "name": "b"
#                 },
#                 {
#                     "name": "a1"
#                 },
#                 {
#                     "name": "b1"
#                 },
#                 {
#                     "name": "c"
#                 },
#                 {
#                     "name": "e"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "a",
#                     "target": "a1",
#                     "value": 5
#                 },
#                 {
#                     "source": "e",
#                     "target": "b",
#                     "value": 3
#                 },
#                 {
#                     "source": "a",
#                     "target": "b1",
#                     "value": 3
#                 },
#                 {
#                     "source": "b1",
#                     "target": "a1",
#                     "value": 1
#                 },
#                 {
#                     "source": "b1",
#                     "target": "c",
#                     "value": 2
#                 },
#                 {
#                     "source": "b",
#                     "target": "c",
#                     "value": 1
#                 }
#             ],
#             "left": "5%",
#             "top": "5%",
#             "right": "20%",
#             "bottom": "10%",
#             "nodeWidth": 20,
#             "nodeGap": 8,
#             "nodeAlign": "justify",
#             "layoutIteration": 32,
#             "orient": "vertical",
#             "draggable": true,
#             "focusNodeAdjacency": "allEdges",
#             "levels": [
#                 {
#                     "depth": 0,
#                     "itemStyle": {
#                         "color": "#eee"
#                     },
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 0.6,
#                         "curveness": 0,
#                         "type": "solid",
#                         "color": "source"
#                     }
#                 }
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 0.4,
#                 "curveness": 0.5,
#                 "type": "solid",
#                 "color": "source"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "sankey"
#             ],
#             "selected": {
#                 "sankey": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_e8e30792a7fe4dc28ef68bb102832c6c.setOption(option_e8e30792a7fe4dc28ef68bb102832c6c);
#         });
#     </script>

# %%
ds.echart(g, "Vertical Sankey sample")

# %%
ds.publish()
# Out:
# Publishing story EChart Sankey examples to the examples space...
# Published at: https://public.deetly.com/examples/c9bc827ec7b50c6aeb167f7bd79f93e8
