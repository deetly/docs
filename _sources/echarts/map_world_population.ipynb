# %% [markdown]
# # ECharts: Geo world population
# > Population from excel
#
# Source: pyecharts samples

# %%
import pandas as pd

# %%
EXCEL_URL = 'https://population.un.org/wpp/Download/Files/1_Indicators%20(Standard)/EXCEL_FILES/1_Population/WPP2019_POP_F01_1_TOTAL_POPULATION_BOTH_SEXES.xlsx'

# %%
df = pd.read_excel(EXCEL_URL, header=16)
df.head(1)
# Out:
#    Index    Variant Region, subregion, country or area * Notes  Country code  \
# 0      1  Estimates                                WORLD   NaN           900
# 1      2  Estimates                UN development groups     a          1803
# 2      3  Estimates               More developed regions     b           901
# 3      4  Estimates               Less developed regions     c           902
# 4      5  Estimates            Least developed countries     d           941
#
#                 Type  Parent code         1950         1951         1952  ...  \
# 0              World            0  2536431.018  2584034.227  2630861.690  ...
# 1    Label/Separator          900          ...          ...          ...  ...
# 2  Development Group         1803   814818.913   824003.512   833720.173  ...
# 3  Development Group         1803  1721612.105  1760030.715  1797141.517  ...
# 4  Development Group          902   195427.785   199180.385   203015.198  ...
#
# ...

# %%
data = df[df['Type']=='Country/Area'][['Region, subregion, country or area *','2020']].values.tolist()

# %%
high = max([x for _, x in data[1:]])
low = min([x for _, x in data[1:]])

# %%
from pyecharts.charts import Map
import pyecharts.options as opts

m = (Map().add(
    maptype='world',
    series_name="World Population",
    data_pair=data[1:],
    is_map_symbol_show=False,
    label_opts=opts.LabelOpts(is_show=False),
))
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="7c975c5715ca4624a87b24d73aa10915" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_7c975c5715ca4624a87b24d73aa10915 = echarts.init(
#                     document.getElementById('7c975c5715ca4624a87b24d73aa10915'), 'white', {renderer: 'canvas'});
#                 var option_7c975c5715ca4624a87b24d73aa10915 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
m.set_global_opts(
    visualmap_opts=opts.VisualMapOpts(
        min_=low,
        max_=high,
        range_text=["max", "min"],
        is_calculable=True,
        range_color=["lightskyblue", "yellow", "orangered"],
    )
)
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="22ef94480dc9452fac6e785e28ec1dd6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_22ef94480dc9452fac6e785e28ec1dd6 = echarts.init(
#                     document.getElementById('22ef94480dc9452fac6e785e28ec1dd6'), 'white', {renderer: 'canvas'});
#                 var option_22ef94480dc9452fac6e785e28ec1dd6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
m = (Map().add(
    maptype='world',
    series_name="World Population",
    data_pair=data[1:],
    is_map_symbol_show=False,
    label_opts=opts.LabelOpts(is_show=False),
    name_map={
        'Dem. Rep. Congo': 'DR Congo',
        'Central African Rep.': 'Central African Republic',
        'S. Sudan': 'South Sudan',
        'Korea': 'South Korea'
    }
).set_global_opts(visualmap_opts=opts.VisualMapOpts(
        min_=low,
        max_=high,
        range_text=["max", "min"],
        is_calculable=True,
        range_color=["lightskyblue", "yellow", "orangered"],
    )
))
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="fc32538b33d64268a649bda96b7ea859" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_fc32538b33d64268a649bda96b7ea859 = echarts.init(
#                     document.getElementById('fc32538b33d64268a649bda96b7ea859'), 'white', {renderer: 'canvas'});
#                 var option_fc32538b33d64268a649bda96b7ea859 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
from pyecharts.charts import MapGlobe

# %%
m = (MapGlobe().add(
    maptype='world',
    series_name="World Population",
    data_pair=data[1:],
    is_map_symbol_show=False,
    label_opts=opts.LabelOpts(is_show=False),
    name_map={
        'Dem. Rep. Congo': 'DR Congo',
        'Central African Rep.': 'Central African Republic',
        'S. Sudan': 'South Sudan',
        'Korea': 'South Korea'
    }
).set_global_opts(visualmap_opts=opts.VisualMapOpts(
        min_=low,
        max_=high,
        range_text=["max", "min"],
        is_calculable=True,
        range_color=["lightskyblue", "yellow", "orangered"],
    )
))
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#     <div id="45ca75c086d84468afd93077d754e962" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-gl', 'world'], function(echarts) {
# 		var canvas_45ca75c086d84468afd93077d754e962 = document.createElement('canvas');
#         var mapChart_45ca75c086d84468afd93077d754e962 = echarts.init(
# 	    canvas_45ca75c086d84468afd93077d754e962, 'white', {width: 4096, height: 2048, renderer: 'canvas'});
#         var mapOption_45ca75c086d84468afd93077d754e962 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
# ...

# %%
help(m)
# Out:
# Help on Map in module pyecharts.charts.basic_charts.map object:
#
# class Map(pyecharts.charts.chart.Chart, MapMixin)
#  |  Map(init_opts: Union[pyecharts.options.global_options.InitOpts, dict] = <pyecharts.options.global_options.InitOpts object at 0x134769c80>)
#  |
#  |  `Base` is the root class for all graphical class, it provides
#  |  part of the initialization parameters and common methods
#  |
#  |  Method resolution order:
#  |      Map
#  |      pyecharts.charts.chart.Chart
#  |      pyecharts.charts.base.Base
#  |      pyecharts.charts.mixins.ChartMixin
#  |      MapMixin
#  |      builtins.object
#  |
#  |  Methods inherited from pyecharts.charts.chart.Chart:
#  |
#  |  __init__(self, init_opts: Union[pyecharts.options.global_options.InitOpts, dict] = <pyecharts.options.global_options.InitOpts object at 0x134769c80>)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
# ...

# %%
m.dump_options()
# Out:
# '{\n    "animation": true,\n    "animationThreshold": 2000,\n    "animationDuration": 1000,\n    "animationEasing": "cubicOut",\n    "animationDelay": 0,\n    "animationDurationUpdate": 300,\n    "animationEasingUpdate": "cubicOut",\n    "animationDelayUpdate": 0,\n    "color": [\n        "#c23531",\n        "#2f4554",\n        "#61a0a8",\n        "#d48265",\n        "#749f83",\n        "#ca8622",\n        "#bda29a",\n        "#6e7074",\n        "#546570",\n        "#c4ccd3",\n        "#f05b72",\n        "#ef5b9c",\n        "#f47920",\n        "#905a3d",\n        "#fab27b",\n        "#2a5caa",\n        "#444693",\n        "#726930",\n        "#b2d235",\n        "#6d8346",\n        "#ac6767",\n        "#1d953f",\n        "#6950a1",\n        "#918597"\n    ],\n    "series": [\n        {\n            "type": "map",\n            "name": "World Population",\n            "label": {\n                "show": false,\n                "position": "top",\n                "margin": 8\n           
# ...
