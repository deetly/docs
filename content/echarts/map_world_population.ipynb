# %% [markdown]
# # Geo world population
# > Population from excel
#
# Source: pyecharts samples

# %%
import pandas as pd

# %%
EXCEL_URL = 'https://population.un.org/wpp/Download/Files/1_Indicators%20(Standard)/EXCEL_FILES/1_Population/WPP2019_POP_F01_1_TOTAL_POPULATION_BOTH_SEXES.xlsx'

# %%
df = pd.read_excel(EXCEL_URL, header=16)
df.head(1)
# Out:
#    Index    Variant Region, subregion, country or area * Notes  Country code  \
# 0      1  Estimates                                WORLD   NaN           900
#
#     Type  Parent code         1950         1951        1952  ...         2011  \
# 0  World            0  2536431.018  2584034.227  2630861.69  ...  7041194.168
#
#           2012         2013         2014         2015         2016       2017  \
# 0  7125827.957  7210582.041  7295290.759  7379796.967  7464021.934  7547858.9
#
#           2018         2019         2020
# 0  7631091.113  7713468.205  7794798.729
#
# [1 rows x 78 columns]

# %%
data = df[df['Type']=='Country/Area'][['Region, subregion, country or area *','2020']].values.tolist()

# %%
high = max([x for _, x in data[1:]])
low = min([x for _, x in data[1:]])

# %%
from pyecharts.charts import Map
import pyecharts.options as opts

m = (Map().add(
    maptype='world',
    series_name="World Population",
    data_pair=data[1:],
    is_map_symbol_show=False,
    label_opts=opts.LabelOpts(is_show=False),
))
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="f2480fdba98943d49442715c07551719" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_f2480fdba98943d49442715c07551719 = echarts.init(
#                     document.getElementById('f2480fdba98943d49442715c07551719'), 'white', {renderer: 'canvas'});
#                 var option_f2480fdba98943d49442715c07551719 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "World Population",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Comoros",
#                     "value": 869.595
#                 },
#                 {
#                     "name": "Djibouti",
#                     "value": 988.002
#                 },
#                 {
#                     "name": "Eritrea",
#                     "value": 3546.427
#                 },
#                 {
#                     "name": "Ethiopia",
#                     "value": 114963.583
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 53771.3
#                 },
#                 {
#                     "name": "Madagascar",
#                     "value": 27691.019
#                 },
#                 {
#                     "name": "Malawi",
#                     "value": 19129.955
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 1271.767
#                 },
#                 {
#                     "name": "Mayotte",
#                     "value": 272.813
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value": 31255.435
#                 },
#                 {
#                     "name": "R\u00e9union",
#                     "value": 895.308
#                 },
#                 {
#                     "name": "Rwanda",
#                     "value": 12952.209
#                 },
#                 {
#                     "name": "Seychelles",
#                     "value": 98.34
#                 },
#                 {
#                     "name": "Somalia",
#                     "value": 15893.219
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 11193.729
#                 },
#                 {
#                     "name": "Uganda",
#                     "value": 45741
#                 },
#                 {
#                     "name": "United Republic of Tanzania",
#                     "value": 59734.213
#                 },
#                 {
#                     "name": "Zambia",
#                     "value": 18383.956
#                 },
#                 {
#                     "name": "Zimbabwe",
#                     "value": 14862.927
#                 },
#                 {
#                     "name": "Angola",
#                     "value": 32866.268
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 26545.864
#                 },
#                 {
#                     "name": "Central African Republic",
#                     "value": 4829.764
#                 },
#                 {
#                     "name": "Chad",
#                     "value": 16425.859
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 5518.092
#                 },
#                 {
#                     "name": "Democratic Republic of the Congo",
#                     "value": 89561.404
#                 },
#                 {
#                     "name": "Equatorial Guinea",
#                     "value": 1402.985
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 2225.728
#                 },
#                 {
#                     "name": "Sao Tome and Principe",
#                     "value": 219.161
#                 },
#                 {
#                     "name": "Botswana",
#                     "value": 2351.625
#                 },
#                 {
#                     "name": "Eswatini",
#                     "value": 1160.164
#                 },
#                 {
#                     "name": "Lesotho",
#                     "value": 2142.252
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 2540.916
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 59308.69
#                 },
#                 {
#                     "name": "Benin",
#                     "value": 12123.198
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 20903.278
#                 },
#                 {
#                     "name": "Cabo Verde",
#                     "value": 555.988
#                 },
#                 {
#                     "name": "C\u00f4te d'Ivoire",
#                     "value": 26378.275
#                 },
#                 {
#                     "name": "Gambia",
#                     "value": 2416.664
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 31072.945
#                 },
#                 {
#                     "name": "Guinea",
#                     "value": 13132.792
#                 },
#                 {
#                     "name": "Guinea-Bissau",
#                     "value": 1967.998
#                 },
#                 {
#                     "name": "Liberia",
#                     "value": 5057.677
#                 },
#                 {
#                     "name": "Mali",
#                     "value": 20250.834
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 4649.66
#                 },
#                 {
#                     "name": "Niger",
#                     "value": 24206.636
#                 },
#                 {
#                     "name": "Nigeria",
#                     "value": 206139.587
#                 },
#                 {
#                     "name": "Saint Helena",
#                     "value": 6.071
#                 },
#                 {
#                     "name": "Senegal",
#                     "value": 16743.93
#                 },
#                 {
#                     "name": "Sierra Leone",
#                     "value": 7976.985
#                 },
#                 {
#                     "name": "Togo",
#                     "value": 8278.737
#                 },
#                 {
#                     "name": "Algeria",
#                     "value": 43851.043
#                 },
#                 {
#                     "name": "Egypt",
#                     "value": 102334.403
#                 },
#                 {
#                     "name": "Libya",
#                     "value": 6871.287
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 36910.558
#                 },
#                 {
#                     "name": "Sudan",
#                     "valu

# %%
m.set_global_opts(
    visualmap_opts=opts.VisualMapOpts(
        min_=low,
        max_=high,
        range_text=["max", "min"],
        is_calculable=True,
        range_color=["lightskyblue", "yellow", "orangered"],
    )
)
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="ea70981e8ce44574801d5a139e456923" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_ea70981e8ce44574801d5a139e456923 = echarts.init(
#                     document.getElementById('ea70981e8ce44574801d5a139e456923'), 'white', {renderer: 'canvas'});
#                 var option_ea70981e8ce44574801d5a139e456923 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "World Population",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Comoros",
#                     "value": 869.595
#                 },
#                 {
#                     "name": "Djibouti",
#                     "value": 988.002
#                 },
#                 {
#                     "name": "Eritrea",
#                     "value": 3546.427
#                 },
#                 {
#                     "name": "Ethiopia",
#                     "value": 114963.583
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 53771.3
#                 },
#                 {
#                     "name": "Madagascar",
#                     "value": 27691.019
#                 },
#                 {
#                     "name": "Malawi",
#                     "value": 19129.955
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 1271.767
#                 },
#                 {
#                     "name": "Mayotte",
#                     "value": 272.813
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value": 31255.435
#                 },
#                 {
#                     "name": "R\u00e9union",
#                     "value": 895.308
#                 },
#                 {
#                     "name": "Rwanda",
#                     "value": 12952.209
#                 },
#                 {
#                     "name": "Seychelles",
#                     "value": 98.34
#                 },
#                 {
#                     "name": "Somalia",
#                     "value": 15893.219
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 11193.729
#                 },
#                 {
#                     "name": "Uganda",
#                     "value": 45741
#                 },
#                 {
#                     "name": "United Republic of Tanzania",
#                     "value": 59734.213
#                 },
#                 {
#                     "name": "Zambia",
#                     "value": 18383.956
#                 },
#                 {
#                     "name": "Zimbabwe",
#                     "value": 14862.927
#                 },
#                 {
#                     "name": "Angola",
#                     "value": 32866.268
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 26545.864
#                 },
#                 {
#                     "name": "Central African Republic",
#                     "value": 4829.764
#                 },
#                 {
#                     "name": "Chad",
#                     "value": 16425.859
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 5518.092
#                 },
#                 {
#                     "name": "Democratic Republic of the Congo",
#                     "value": 89561.404
#                 },
#                 {
#                     "name": "Equatorial Guinea",
#                     "value": 1402.985
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 2225.728
#                 },
#                 {
#                     "name": "Sao Tome and Principe",
#                     "value": 219.161
#                 },
#                 {
#                     "name": "Botswana",
#                     "value": 2351.625
#                 },
#                 {
#                     "name": "Eswatini",
#                     "value": 1160.164
#                 },
#                 {
#                     "name": "Lesotho",
#                     "value": 2142.252
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 2540.916
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 59308.69
#                 },
#                 {
#                     "name": "Benin",
#                     "value": 12123.198
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 20903.278
#                 },
#                 {
#                     "name": "Cabo Verde",
#                     "value": 555.988
#                 },
#                 {
#                     "name": "C\u00f4te d'Ivoire",
#                     "value": 26378.275
#                 },
#                 {
#                     "name": "Gambia",
#                     "value": 2416.664
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 31072.945
#                 },
#                 {
#                     "name": "Guinea",
#                     "value": 13132.792
#                 },
#                 {
#                     "name": "Guinea-Bissau",
#                     "value": 1967.998
#                 },
#                 {
#                     "name": "Liberia",
#                     "value": 5057.677
#                 },
#                 {
#                     "name": "Mali",
#                     "value": 20250.834
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 4649.66
#                 },
#                 {
#                     "name": "Niger",
#                     "value": 24206.636
#                 },
#                 {
#                     "name": "Nigeria",
#                     "value": 206139.587
#                 },
#                 {
#                     "name": "Saint Helena",
#                     "value": 6.071
#                 },
#                 {
#                     "name": "Senegal",
#                     "value": 16743.93
#                 },
#                 {
#                     "name": "Sierra Leone",
#                     "value": 7976.985
#                 },
#                 {
#                     "name": "Togo",
#                     "value": 8278.737
#                 },
#                 {
#                     "name": "Algeria",
#                     "value": 43851.043
#                 },
#                 {
#                     "name": "Egypt",
#                     "value": 102334.403
#                 },
#                 {
#                     "name": "Libya",
#                     "value": 6871.287
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 36910.558
#                 },
#                 {
#                     "name": "Sudan",
#                     "valu

# %%
m = (Map().add(
    maptype='world',
    series_name="World Population",
    data_pair=data[1:],
    is_map_symbol_show=False,
    label_opts=opts.LabelOpts(is_show=False),
    name_map={
        'Dem. Rep. Congo': 'DR Congo',
        'Central African Rep.': 'Central African Republic',
        'S. Sudan': 'South Sudan',
        'Korea': 'South Korea'
    }
).set_global_opts(visualmap_opts=opts.VisualMapOpts(
        min_=low,
        max_=high,
        range_text=["max", "min"],
        is_calculable=True,
        range_color=["lightskyblue", "yellow", "orangered"],
    )
))
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="42345d3d7e904e5d90630970e5d7737e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_42345d3d7e904e5d90630970e5d7737e = echarts.init(
#                     document.getElementById('42345d3d7e904e5d90630970e5d7737e'), 'white', {renderer: 'canvas'});
#                 var option_42345d3d7e904e5d90630970e5d7737e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "World Population",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Comoros",
#                     "value": 869.595
#                 },
#                 {
#                     "name": "Djibouti",
#                     "value": 988.002
#                 },
#                 {
#                     "name": "Eritrea",
#                     "value": 3546.427
#                 },
#                 {
#                     "name": "Ethiopia",
#                     "value": 114963.583
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 53771.3
#                 },
#                 {
#                     "name": "Madagascar",
#                     "value": 27691.019
#                 },
#                 {
#                     "name": "Malawi",
#                     "value": 19129.955
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 1271.767
#                 },
#                 {
#                     "name": "Mayotte",
#                     "value": 272.813
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value": 31255.435
#                 },
#                 {
#                     "name": "R\u00e9union",
#                     "value": 895.308
#                 },
#                 {
#                     "name": "Rwanda",
#                     "value": 12952.209
#                 },
#                 {
#                     "name": "Seychelles",
#                     "value": 98.34
#                 },
#                 {
#                     "name": "Somalia",
#                     "value": 15893.219
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 11193.729
#                 },
#                 {
#                     "name": "Uganda",
#                     "value": 45741
#                 },
#                 {
#                     "name": "United Republic of Tanzania",
#                     "value": 59734.213
#                 },
#                 {
#                     "name": "Zambia",
#                     "value": 18383.956
#                 },
#                 {
#                     "name": "Zimbabwe",
#                     "value": 14862.927
#                 },
#                 {
#                     "name": "Angola",
#                     "value": 32866.268
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 26545.864
#                 },
#                 {
#                     "name": "Central African Republic",
#                     "value": 4829.764
#                 },
#                 {
#                     "name": "Chad",
#                     "value": 16425.859
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 5518.092
#                 },
#                 {
#                     "name": "Democratic Republic of the Congo",
#                     "value": 89561.404
#                 },
#                 {
#                     "name": "Equatorial Guinea",
#                     "value": 1402.985
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 2225.728
#                 },
#                 {
#                     "name": "Sao Tome and Principe",
#                     "value": 219.161
#                 },
#                 {
#                     "name": "Botswana",
#                     "value": 2351.625
#                 },
#                 {
#                     "name": "Eswatini",
#                     "value": 1160.164
#                 },
#                 {
#                     "name": "Lesotho",
#                     "value": 2142.252
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 2540.916
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 59308.69
#                 },
#                 {
#                     "name": "Benin",
#                     "value": 12123.198
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 20903.278
#                 },
#                 {
#                     "name": "Cabo Verde",
#                     "value": 555.988
#                 },
#                 {
#                     "name": "C\u00f4te d'Ivoire",
#                     "value": 26378.275
#                 },
#                 {
#                     "name": "Gambia",
#                     "value": 2416.664
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 31072.945
#                 },
#                 {
#                     "name": "Guinea",
#                     "value": 13132.792
#                 },
#                 {
#                     "name": "Guinea-Bissau",
#                     "value": 1967.998
#                 },
#                 {
#                     "name": "Liberia",
#                     "value": 5057.677
#                 },
#                 {
#                     "name": "Mali",
#                     "value": 20250.834
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 4649.66
#                 },
#                 {
#                     "name": "Niger",
#                     "value": 24206.636
#                 },
#                 {
#                     "name": "Nigeria",
#                     "value": 206139.587
#                 },
#                 {
#                     "name": "Saint Helena",
#                     "value": 6.071
#                 },
#                 {
#                     "name": "Senegal",
#                     "value": 16743.93
#                 },
#                 {
#                     "name": "Sierra Leone",
#                     "value": 7976.985
#                 },
#                 {
#                     "name": "Togo",
#                     "value": 8278.737
#                 },
#                 {
#                     "name": "Algeria",
#                     "value": 43851.043
#                 },
#                 {
#                     "name": "Egypt",
#                     "value": 102334.403
#                 },
#                 {
#                     "name": "Libya",
#                     "value": 6871.287
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 36910.558
#                 },
#                 {
#                     "name": "Sudan",
#                     "valu

# %%
from pyecharts.charts import MapGlobe

# %%
m = (MapGlobe().add(
    maptype='world',
    series_name="World Population",
    data_pair=data[1:],
    is_map_symbol_show=False,
    label_opts=opts.LabelOpts(is_show=False),
    name_map={
        'Dem. Rep. Congo': 'DR Congo',
        'Central African Rep.': 'Central African Republic',
        'S. Sudan': 'South Sudan',
        'Korea': 'South Korea'
    }
).set_global_opts(visualmap_opts=opts.VisualMapOpts(
        min_=low,
        max_=high,
        range_text=["max", "min"],
        is_calculable=True,
        range_color=["lightskyblue", "yellow", "orangered"],
    )
))
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#     <div id="ca50a8f05ef54649bda5ec10835923aa" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-gl', 'world'], function(echarts) {
# 		var canvas_ca50a8f05ef54649bda5ec10835923aa = document.createElement('canvas');
#         var mapChart_ca50a8f05ef54649bda5ec10835923aa = echarts.init(
# 	    canvas_ca50a8f05ef54649bda5ec10835923aa, 'white', {width: 4096, height: 2048, renderer: 'canvas'});
#         var mapOption_ca50a8f05ef54649bda5ec10835923aa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "World Population",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Comoros",
#                     "value": 869.595
#                 },
#                 {
#                     "name": "Djibouti",
#                     "value": 988.002
#                 },
#                 {
#                     "name": "Eritrea",
#                     "value": 3546.427
#                 },
#                 {
#                     "name": "Ethiopia",
#                     "value": 114963.583
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 53771.3
#                 },
#                 {
#                     "name": "Madagascar",
#                     "value": 27691.019
#                 },
#                 {
#                     "name": "Malawi",
#                     "value": 19129.955
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 1271.767
#                 },
#                 {
#                     "name": "Mayotte",
#                     "value": 272.813
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value": 31255.435
#                 },
#                 {
#                     "name": "R\u00e9union",
#                     "value": 895.308
#                 },
#                 {
#                     "name": "Rwanda",
#                     "value": 12952.209
#                 },
#                 {
#                     "name": "Seychelles",
#                     "value": 98.34
#                 },
#                 {
#                     "name": "Somalia",
#                     "value": 15893.219
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 11193.729
#                 },
#                 {
#                     "name": "Uganda",
#                     "value": 45741
#                 },
#                 {
#                     "name": "United Republic of Tanzania",
#                     "value": 59734.213
#                 },
#                 {
#                     "name": "Zambia",
#                     "value": 18383.956
#                 },
#                 {
#                     "name": "Zimbabwe",
#                     "value": 14862.927
#                 },
#                 {
#                     "name": "Angola",
#                     "value": 32866.268
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 26545.864
#                 },
#                 {
#                     "name": "Central African Republic",
#                     "value": 4829.764
#                 },
#                 {
#                     "name": "Chad",
#                     "value": 16425.859
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 5518.092
#                 },
#                 {
#                     "name": "Democratic Republic of the Congo",
#                     "value": 89561.404
#                 },
#                 {
#                     "name": "Equatorial Guinea",
#                     "value": 1402.985
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 2225.728
#                 },
#                 {
#                     "name": "Sao Tome and Principe",
#                     "value": 219.161
#                 },
#                 {
#                     "name": "Botswana",
#                     "value": 2351.625
#                 },
#                 {
#                     "name": "Eswatini",
#                     "value": 1160.164
#                 },
#                 {
#                     "name": "Lesotho",
#                     "value": 2142.252
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 2540.916
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 59308.69
#                 },
#                 {
#                     "name": "Benin",
#                     "value": 12123.198
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 20903.278
#                 },
#                 {
#                     "name": "Cabo Verde",
#                     "value": 555.988
#                 },
#                 {
#                     "name": "C\u00f4te d'Ivoire",
#                     "value": 26378.275
#                 },
#                 {
#                     "name": "Gambia",
#                     "value": 2416.664
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 31072.945
#                 },
#                 {
#                     "name": "Guinea",
#                     "value": 13132.792
#                 },
#                 {
#                     "name": "Guinea-Bissau",
#                     "value": 1967.998
#                 },
#                 {
#                     "name": "Liberia",
#                     "value": 5057.677
#                 },
#                 {
#                     "name": "Mali",
#                     "value": 20250.834
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 4649.66
#                 },
#                 {
#                     "name": "Niger",
#                     "value": 24206.636
#                 },
#                 {
#                     "name": "Nigeria",
#                     "value": 206139.587
#                 },
#                 {
#                     "name": "Saint Helena",
#                     "value": 6.071
#                 },
#                 {
#                     "name": "Senegal",
#                     "value": 16743.93
#                 },
#                 {
#                     "name": "Sierra Leone",
#                     "value": 7976.985
#                 },
#                 {
#                     "name": "Togo",
#                     "value": 8278.737
#                 },
#                 {
#                     "name": "Algeria",
#                     "value": 43851.043
#                 },
#                 {
#                     "name": "Egypt",
#                     "value": 102334.403
#                 },
#                 {
#                     "name": "Libya",
#                     "value": 6871.287
#                 },
#                 {
#                     "name": "Morocco",
